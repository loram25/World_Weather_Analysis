# %%
import pandas as pd
import numpy as np
import random
import requests
import gmaps
from citipy import citipy
from datetime import datetime
from config import weather_api_key, g_key

# %%
lats=np.random.uniform(low=-90.000,high=90.000,size=1500)
lngs=np.random.uniform(low=-180.000,high=180.000,size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

coordinates= list(lat_lngs)

cities=[]

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 598

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20e4d63acc61b0031b5f702c3488db55'

# %%
city_data=[]

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count=1
set_count=1

for i, city in enumerate(cities):

    if (i % 50==0 and i >=50):
        set_count += 1
        record_count = 1

    city_url = url + '&q=' + city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count+=1

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_descr = city_weather['weather'][0]['description']
        try:
            city_rain = city_weather['rain']['3h']
        except:
            city_rain = 0.00
            pass
        try:
            city_snow = city_weather['snow']['3h']
        except:
            city_snow = 0.00
            pass
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descr,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow,
                          "Country": city_country,
                          "Date": city_date})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aras
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | naryan-mar
# Processing Record 5 of Set 1 | umm lajj
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | canico
# Processing Record 13 of Set 1 | fallon
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | gumushane
# City not found. Skipping...
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | labuhan
# Processing Record 19 of Set 1 | cayenne
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | tanshui
# City not found. Skipping...
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | kamsack
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | beringovskiy
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | puerto escondido
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | chuka
# Processing Record 46 of Set 1 | marsh harbour
# Processing Record 47 of Set 1 | metu
# Processing Record 48 of Set 1 | presidencia roque saenz pena
# Processing Record 49 of Set 1 | yongan
# Processing Record 50 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 2 | beyneu
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | barra patuca
# Processing Record 7 of Set 2 | eyl
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | severnoye
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | nelson bay
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | novita
# Processing Record 14 of Set 2 | lulea
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | gizo
# Processing Record 17 of Set 2 | akyab
# Processing Record 18 of Set 2 | sechura
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | paragominas
# Processing Record 22 of Set 2 | rabo de peixe
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | bahia de caraquez
# Processing Record 27 of Set 2 | matara
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | miraflores
# Processing Record 32 of Set 2 | glens falls
# Processing Record 33 of Set 2 | palmer
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | elizabeth city
# Processing Record 38 of Set 2 | si bun ruang
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | bellefontaine
# Processing Record 41 of Set 2 | santa maria do suacui
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | ngaoundere
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | manadhoo
# Processing Record 50 of Set 2 | novyy urgal
# Processing Record 1 of Set 3 | sangar
# Processing Record 2 of Set 3 | port washington
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | lavrentiya
# Processing Record 6 of Set 3 | holzminden
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | waipawa
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | san andres
# Processing Record 13 of Set 3 | albany
# Processing Record 14 of Set 3 | tupik
# Processing Record 15 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | saint-louis
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | murray bridge
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | skibbereen
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | marawi
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | beloha
# Processing Record 30 of Set 3 | sirvintos
# Processing Record 31 of Set 3 | ukiah
# Processing Record 32 of Set 3 | moree
# Processing Record 33 of Set 3 | teknaf
# Processing Record 34 of Set 3 | baracoa
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | mogadishu
# Processing Record 37 of Set 3 | poum
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | fort nelson
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | coquimbo
# Processing Record 42 of Set 3 | sambava
# Processing Record 43 of Set 3 | senno
# Processing Record 44 of Set 3 | zhoucheng
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | villa oliva
# City not found. Skipping...
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | nantucket
# Processing Record 49 of Set 3 | sivas
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | katherine
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | harper
# Processing Record 5 of Set 4 | juigalpa
# Processing Record 6 of Set 4 | porto novo
# Processing Record 7 of Set 4 | fairbanks
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | den helder
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | ngunguru
# Processing Record 12 of Set 4 | bubaque
# Processing Record 13 of Set 4 | sur
# Processing Record 14 of Set 4 | sitka
# Processing Record 15 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 4 | buchanan
# Processing Record 17 of Set 4 | dubti
# Processing Record 18 of Set 4 | lima duarte
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | van
# Processing Record 21 of Set 4 | nome
# Processing Record 22 of Set 4 | kijang
# Processing Record 23 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | kantang
# Processing Record 27 of Set 4 | bandarbeyla
# Processing Record 28 of Set 4 | san carlos del zulia
# Processing Record 29 of Set 4 | gutierrez
# Processing Record 30 of Set 4 | tashtyp
# Processing Record 31 of Set 4 | le port
# Processing Record 32 of Set 4 | marzuq
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | faya
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | partanna
# Processing Record 37 of Set 4 | lodja
# Processing Record 38 of Set 4 | evensk
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | zhangjiakou
# Processing Record 41 of Set 4 | phonhong
# Processing Record 42 of Set 4 | ritchie
# Processing Record 43 of Set 4 | ayorou
# Processing Record 44 of Set 4 | nerchinskiy zavod
# Processing Record 45 of Set 4 | tacoronte
# Processing Record 46 of Set 4 | deputatskiy
# Processing Record 47 of Set 4 | half moon bay
# Processing Record 48 of Set 4 | diffa
# Processing Record 49 of Set 4 | acarau
# Processing Record 50 of Set 4 | tomatlan
# Processing Record 1 of Set 5 | krasnoselkup
# Processing Record 2 of Set 5 | hithadhoo
# Processing Record 3 of Set 5 | nikki
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | east london
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | belaya gora
# Processing Record 8 of Set 5 | bathsheba
# Processing Record 9 of Set 5 | auray
# Processing Record 10 of Set 5 | najran
# Processing Record 11 of Set 5 | buala
# Processing Record 12 of Set 5 | hofn
# Processing Record 13 of Set 5 | ternate
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | qaqortoq
# Processing Record 17 of Set 5 | lebedinyy
# Processing Record 18 of Set 5 | pochutla
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | richards bay
# Processing Record 23 of Set 5 | teavaro
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | ankang
# Processing Record 26 of Set 5 | astaneh-ye ashrafiyeh
# Processing Record 27 of Set 5 | muzquiz
# City not found. Skipping...
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | alice springs
# Processing Record 30 of Set 5 | cabra
# Processing Record 31 of Set 5 | college
# Processing Record 32 of Set 5 | la rioja
# Processing Record 33 of Set 5 | saint-leu
# Processing Record 34 of Set 5 | santa cruz
# Processing Record 35 of Set 5 | puerto narino
# Processing Record 36 of Set 5 | poltsamaa
# Processing Record 37 of Set 5 | ejido
# Processing Record 38 of Set 5 | fort-shevchenko
# Processing Record 39 of Set 5 | son la
# Processing Record 40 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | tual
# Processing Record 43 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | lazaro cardenas
# Processing Record 49 of Set 5 | xiaolingwei
# Processing Record 50 of Set 5 | oktyabrskiy
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | si satchanalai
# Processing Record 3 of Set 6 | othonoi
# City not found. Skipping...
# Processing Record 4 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 6 | pisco
# Processing Record 6 of Set 6 | giovinazzo
# Processing Record 7 of Set 6 | dwarka
# Processing Record 8 of Set 6 | tommot
# Processing Record 9 of Set 6 | ankazoabo
# Processing Record 10 of Set 6 | okato
# Processing Record 11 of Set 6 | la ronge
# Processing Record 12 of Set 6 | nuuk
# Processing Record 13 of Set 6 | kahului
# Processing Record 14 of Set 6 | salamiyah
# Processing Record 15 of Set 6 | honolulu
# Processing Record 16 of Set 6 | kupang
# Processing Record 17 of Set 6 | paamiut
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | iskateley
# Processing Record 20 of Set 6 | kodinsk
# Processing Record 21 of Set 6 | talaya
# Processing Record 22 of Set 6 | cap malheureux
# Processing Record 23 of Set 6 | kieta
# Processing Record 24 of Set 6 | tilichiki
# Processing Record 25 of Set 6 | palamos
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | safranbolu
# Processing Record 28 of Set 6 | veraval
# Processing Record 29 of Set 6 | moba
# Processing Record 30 of Set 6 | north bend
# Processing Record 31 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 32 of Set 6 | chardara
# Processing Record 33 of Set 6 | shimoda
# Processing Record 34 of Set 6 | sladkovo
# Processing Record 35 of Set 6 | colquechaca
# Processing Record 36 of Set 6 | kiskore
# Processing Record 37 of Set 6 | maningrida
# Processing Record 38 of Set 6 | pleasanton
# Processing Record 39 of Set 6 | biloela
# Processing Record 40 of Set 6 | coruripe
# Processing Record 41 of Set 6 | soyo
# Processing Record 42 of Set 6 | verkhnyaya khava
# Processing Record 43 of Set 6 | zinder
# Processing Record 44 of Set 6 | khandyga
# Processing Record 45 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 6 | mazagao
# Processing Record 47 of Set 6 | taksimo
# Processing Record 48 of Set 6 | bengkulu
# Processing Record 49 of Set 6 | sena madureira
# Processing Record 50 of Set 6 | guerrero negro
# Processing Record 1 of Set 7 | brasilia de minas
# Processing Record 2 of Set 7 | tanete
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | oksfjord
# Processing Record 5 of Set 7 | ararangua
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | anchorage
# Processing Record 8 of Set 7 | sao filipe
# Processing Record 9 of Set 7 | lompoc
# Processing Record 10 of Set 7 | porto santo
# Processing Record 11 of Set 7 | maues
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | bairiki
# Processing Record 14 of Set 7 | kamenka
# Processing Record 15 of Set 7 | abu kamal
# Processing Record 16 of Set 7 | hasaki
# Processing Record 17 of Set 7 | kaitangata
# Processing Record 18 of Set 7 | arraial do cabo
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | honningsvag
# Processing Record 21 of Set 7 | saint anthony
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | mar del plata
# Processing Record 24 of Set 7 | atherton
# Processing Record 25 of Set 7 | grindavik
# Processing Record 26 of Set 7 | banda aceh
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | chongqing
# Processing Record 30 of Set 7 | kropotkin
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | mehamn
# Processing Record 33 of Set 7 | gisborne
# Processing Record 34 of Set 7 | fougamou
# Processing Record 35 of Set 7 | okakarara
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 7 | diego de almagro
# Processing Record 39 of Set 7 | clyde river
# Processing Record 40 of Set 7 | rutul
# Processing Record 41 of Set 7 | nambucca heads
# Processing Record 42 of Set 7 | rio grande
# Processing Record 43 of Set 7 | acari
# Processing Record 44 of Set 7 | tabas
# Processing Record 45 of Set 7 | panacan
# Processing Record 46 of Set 7 | camocim
# Processing Record 47 of Set 7 | cherskiy
# Processing Record 48 of Set 7 | calama
# Processing Record 49 of Set 7 | mayo
# Processing Record 50 of Set 7 | erzin
# Processing Record 1 of Set 8 | awjilah
# Processing Record 2 of Set 8 | martapura
# Processing Record 3 of Set 8 | muisne
# Processing Record 4 of Set 8 | kosa
# Processing Record 5 of Set 8 | ambulu
# Processing Record 6 of Set 8 | katobu
# Processing Record 7 of Set 8 | kenai
# Processing Record 8 of Set 8 | pitkyaranta
# Processing Record 9 of Set 8 | norman wells
# Processing Record 10 of Set 8 | taltal
# Processing Record 11 of Set 8 | ono
# Processing Record 12 of Set 8 | santa rosa
# Processing Record 13 of Set 8 | srandakan
# Processing Record 14 of Set 8 | burica
# City not found. Skipping...
# Processing Record 15 of Set 8 | ballina
# Processing Record 16 of Set 8 | bandiagara
# Processing Record 17 of Set 8 | chignahuapan
# Processing Record 18 of Set 8 | boa vista
# Processing Record 19 of Set 8 | praia
# Processing Record 20 of Set 8 | sao geraldo do araguaia
# Processing Record 21 of Set 8 | kuchera
# Processing Record 22 of Set 8 | kyra
# Processing Record 23 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 8 | salvador
# Processing Record 25 of Set 8 | berezovyy
# Processing Record 26 of Set 8 | broome
# Processing Record 27 of Set 8 | sao francisco do sul
# Processing Record 28 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 8 | miri
# Processing Record 30 of Set 8 | talcahuano
# Processing Record 31 of Set 8 | luena
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | bardiyah
# Processing Record 34 of Set 8 | toledo
# Processing Record 35 of Set 8 | saint-pierre
# Processing Record 36 of Set 8 | salaga
# Processing Record 37 of Set 8 | tuxtla
# Processing Record 38 of Set 8 | lebedyn
# Processing Record 39 of Set 8 | haimen
# Processing Record 40 of Set 8 | opalenica
# Processing Record 41 of Set 8 | catalao
# Processing Record 42 of Set 8 | kimberley
# Processing Record 43 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 8 | saint-augustin
# Processing Record 45 of Set 8 | pandan
# Processing Record 46 of Set 8 | iranshahr
# Processing Record 47 of Set 8 | ranong
# Processing Record 48 of Set 8 | morgan city
# Processing Record 49 of Set 8 | abu samrah
# Processing Record 50 of Set 8 | mapiripan
# Processing Record 1 of Set 9 | challapata
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | nuevitas
# Processing Record 4 of Set 9 | durham
# Processing Record 5 of Set 9 | arman
# Processing Record 6 of Set 9 | monte patria
# Processing Record 7 of Set 9 | guarda
# Processing Record 8 of Set 9 | lodwar
# Processing Record 9 of Set 9 | calabozo
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | nagato
# Processing Record 12 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 9 | sobolevo
# Processing Record 14 of Set 9 | singaraja
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | maniitsoq
# Processing Record 17 of Set 9 | ulladulla
# Processing Record 18 of Set 9 | sioux lookout
# Processing Record 19 of Set 9 | sitamau
# Processing Record 20 of Set 9 | asfi
# Processing Record 21 of Set 9 | baruni
# Processing Record 22 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 9 | tankhoy
# Processing Record 25 of Set 9 | quilmana
# Processing Record 26 of Set 9 | maromitsa
# Processing Record 27 of Set 9 | huarmey
# Processing Record 28 of Set 9 | santa isabel do rio negro
# Processing Record 29 of Set 9 | chara
# Processing Record 30 of Set 9 | brigantine
# Processing Record 31 of Set 9 | porbandar
# Processing Record 32 of Set 9 | praia da vitoria
# Processing Record 33 of Set 9 | ipameri
# Processing Record 34 of Set 9 | valparaiso
# Processing Record 35 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 9 | lagoa
# Processing Record 37 of Set 9 | zhanaozen
# Processing Record 38 of Set 9 | killarney
# Processing Record 39 of Set 9 | bulawayo
# Processing Record 40 of Set 9 | ellisras
# Processing Record 41 of Set 9 | huanren
# Processing Record 42 of Set 9 | matamoros
# Processing Record 43 of Set 9 | natal
# Processing Record 44 of Set 9 | gazli
# Processing Record 45 of Set 9 | jiaonan
# Processing Record 46 of Set 9 | agadez
# Processing Record 47 of Set 9 | drezdenko
# Processing Record 48 of Set 9 | grand baie
# Processing Record 49 of Set 9 | killybegs
# Processing Record 50 of Set 9 | kasongo-lunda
# Processing Record 1 of Set 10 | yining
# Processing Record 2 of Set 10 | ust-nera
# Processing Record 3 of Set 10 | margate
# Processing Record 4 of Set 10 | chau doc
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 10 | great falls
# Processing Record 8 of Set 10 | abu zabad
# Processing Record 9 of Set 10 | merano
# Processing Record 10 of Set 10 | melgar
# Processing Record 11 of Set 10 | durban
# Processing Record 12 of Set 10 | rio gallegos
# Processing Record 13 of Set 10 | garbolovo
# Processing Record 14 of Set 10 | churapcha
# Processing Record 15 of Set 10 | cubarral
# Processing Record 16 of Set 10 | okhotsk
# Processing Record 17 of Set 10 | goundi
# Processing Record 18 of Set 10 | poronaysk
# Processing Record 19 of Set 10 | yenagoa
# Processing Record 20 of Set 10 | riyadh
# Processing Record 21 of Set 10 | ngorongoro
# Processing Record 22 of Set 10 | collie
# Processing Record 23 of Set 10 | eirunepe
# Processing Record 24 of Set 10 | baruun-urt
# Processing Record 25 of Set 10 | vaitape
# Processing Record 26 of Set 10 | ambilobe
# Processing Record 27 of Set 10 | rudnya
# Processing Record 28 of Set 10 | shelton
# Processing Record 29 of Set 10 | concordia
# Processing Record 30 of Set 10 | cardston
# Processing Record 31 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 10 | castelu
# Processing Record 33 of Set 10 | sorland
# Processing Record 34 of Set 10 | amahai
# Processing Record 35 of Set 10 | shache
# Processing Record 36 of Set 10 | shu
# Processing Record 37 of Set 10 | sabla
# Processing Record 38 of Set 10 | kashi
# Processing Record 39 of Set 10 | esil
# Processing Record 40 of Set 10 | tazovskiy
# Processing Record 41 of Set 10 | tevaitoa
# Processing Record 42 of Set 10 | payyannur
# Processing Record 43 of Set 10 | omboue
# Processing Record 44 of Set 10 | codrington
# Processing Record 45 of Set 10 | dargaville
# Processing Record 46 of Set 10 | san patricio
# Processing Record 47 of Set 10 | kaspiyskiy
# Processing Record 48 of Set 10 | rehoboth
# Processing Record 49 of Set 10 | aldan
# Processing Record 50 of Set 10 | road town
# Processing Record 1 of Set 11 | ca mau
# Processing Record 2 of Set 11 | leticia
# Processing Record 3 of Set 11 | lata
# Processing Record 4 of Set 11 | honiara
# Processing Record 5 of Set 11 | kedrovyy
# Processing Record 6 of Set 11 | os
# City not found. Skipping...
# Processing Record 7 of Set 11 | samsun
# Processing Record 8 of Set 11 | severo-kurilsk
# Processing Record 9 of Set 11 | staryy nadym
# Processing Record 10 of Set 11 | quatre cocos
# Processing Record 11 of Set 11 | willemstad
# Processing Record 12 of Set 11 | alihe
# Processing Record 13 of Set 11 | ariquemes
# Processing Record 14 of Set 11 | akdepe
# Processing Record 15 of Set 11 | chadiza
# Processing Record 16 of Set 11 | wattegama
# Processing Record 17 of Set 11 | terebovlya
# Processing Record 18 of Set 11 | blagoyevo
# Processing Record 19 of Set 11 | agirish
# Processing Record 20 of Set 11 | podbelsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | lahat
# Processing Record 22 of Set 11 | ouallam
# Processing Record 23 of Set 11 | naron
# Processing Record 24 of Set 11 | ixtapa
# Processing Record 25 of Set 11 | port pirie
# Processing Record 26 of Set 11 | bavly
# Processing Record 27 of Set 11 | general roca
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | sola
# Processing Record 30 of Set 11 | ramotswa
# Processing Record 31 of Set 11 | vila do maio
# Processing Record 32 of Set 11 | glendive
# Processing Record 33 of Set 11 | russell
# Processing Record 34 of Set 11 | sarangani
# Processing Record 35 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 11 | chaman
# Processing Record 37 of Set 11 | yeppoon
# Processing Record 38 of Set 11 | henties bay
# Processing Record 39 of Set 11 | cascais
# Processing Record 40 of Set 11 | craig
# Processing Record 41 of Set 11 | kathmandu
# Processing Record 42 of Set 11 | westport
# Processing Record 43 of Set 11 | kismayo
# Processing Record 44 of Set 11 | pemangkat
# Processing Record 45 of Set 11 | sorong
# Processing Record 46 of Set 11 | acapulco
# Processing Record 47 of Set 11 | aksarka
# Processing Record 48 of Set 11 | vanimo
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | alindao
# Processing Record 1 of Set 12 | cravo norte
# Processing Record 2 of Set 12 | dzhebariki-khaya
# Processing Record 3 of Set 12 | havelock
# Processing Record 4 of Set 12 | jalor
# Processing Record 5 of Set 12 | arkhipo-osipovka
# Processing Record 6 of Set 12 | neiafu
# Processing Record 7 of Set 12 | jacmel
# Processing Record 8 of Set 12 | kavaratti
# Processing Record 9 of Set 12 | saint-joseph
# Processing Record 10 of Set 12 | guadalajara
# Processing Record 11 of Set 12 | gawler
# Processing Record 12 of Set 12 | caravelas
# Processing Record 13 of Set 12 | novyy urengoy
# Processing Record 14 of Set 12 | marabba
# Processing Record 15 of Set 12 | letterkenny
# Processing Record 16 of Set 12 | bad camberg
# Processing Record 17 of Set 12 | mizdah
# Processing Record 18 of Set 12 | vung tau
# Processing Record 19 of Set 12 | vedi
# Processing Record 20 of Set 12 | agropoli
# Processing Record 21 of Set 12 | verkhnevilyuysk
# Processing Record 22 of Set 12 | wewak
# Processing Record 23 of Set 12 | abnub
# Processing Record 24 of Set 12 | villaviciosa
# Processing Record 25 of Set 12 | oxapampa
# Processing Record 26 of Set 12 | san jose
# Processing Record 27 of Set 12 | trairi
# Processing Record 28 of Set 12 | banepa
# Processing Record 29 of Set 12 | nikolayevka
# Processing Record 30 of Set 12 | usinsk
# Processing Record 31 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | soure
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | port moresby
# Processing Record 36 of Set 12 | romitan
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | manokwari
# Processing Record 39 of Set 12 | bilibino
# Processing Record 40 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 12 | san quintin
# Processing Record 42 of Set 12 | ko samui
# Processing Record 43 of Set 12 | whitefish
# Processing Record 44 of Set 12 | whitianga
# Processing Record 45 of Set 12 | bilma
# Processing Record 46 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 12 | muroto
# Processing Record 48 of Set 12 | udachnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=20e4d63acc61b0031b5f702c3488db55&q=udachnyy'

# %%
city_data=pd.DataFrame(city_data)
city_data.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Aras  42.56   -2.36     64.40        34          98       13.87
# 1   Butaritari   3.07  172.79     83.16        80          69       21.00
# 2  Port Alfred -33.59   26.89     69.01        84           0        5.01
# 3   Naryan-Mar  67.67   53.09     15.57        93         100       16.78
# 4     Umm Lajj  25.02   37.27     64.71        57           0       11.90
#
#   Current Description  Rain inches (last 3 hrs)  Snow inches (last 3 hrs)  \
# 0     overcast clouds                      0.00                      0.00
# 1          light rain                      0.19                      0.00
# 2           clear sky                      0.00                      0.00
# 3          light snow                      0.00                      0.31
# 4           clear sky                      0.00                      0.00
#
#   Country                 Date
# 0      ES  2020-03-01 16:40:41
# 1      KI  2020-03-01 16:40:41
# 2      ZA  2020-03-01 16:40:42
# 3      RU  2020-03-01 16:40:42
# 4      SA  2020-03-01 16:40:42

# %%
new_column_order=['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description','Rain inches (last 3 hrs)',"Snow inches (last 3 hrs)"]

# %%
city_data=city_data[new_column_order]
city_data.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0            Aras      ES  2020-03-01 16:40:41  42.56   -2.36     64.40
# 1      Butaritari      KI  2020-03-01 16:40:41   3.07  172.79     83.16
# 2     Port Alfred      ZA  2020-03-01 16:40:42 -33.59   26.89     69.01
# 3      Naryan-Mar      RU  2020-03-01 16:40:42  67.67   53.09     15.57
# 4        Umm Lajj      SA  2020-03-01 16:40:42  25.02   37.27     64.71
# 5      Georgetown      MY  2020-03-01 16:37:54   5.41  100.34     84.20
# 6         Rikitea      PF  2020-03-01 16:40:42 -23.12 -134.97     80.19
# 7  Ribeira Grande      PT  2020-03-01 16:40:42  38.52  -28.70     64.40
# 8        Hermanus      ZA  2020-03-01 16:40:43 -34.42   19.23     73.99
# 9         Mataura      NZ  2020-03-01 16:40:43 -46.19  168.86     52.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        34          98       13.87     overcast clouds
# 1        80          69       21.00          light rain
# 2        84           0        5.01           clear sky
# 3        93         100       16.78          light snow
# 4        57           0       11.90           clear sky
# 5        88          20        1.95          few clouds
# 6        80         100       12.10          light rain
# 7        88          75       23.04       broken clouds
# 8        73          50       11.01    scattered clouds
# 9        92          56        1.99       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                      0.00
# 1                      0.19                      0.00
# 2                      0.00                      0.00
# 3                      0.00                      0.31
# 4                      0.00                      0.00
# 5                      0.00                      0.00
# 6                      1.69                      0.00
# 7                      0.00                      0.00
# 8                      0.00                      0.00
# 9                      0.00                      0.00

# %%
output_data_file='Weather_Database.csv'
city_data.to_csv(output_data_file, index_label='City_ID')

# %%
city_data.notnull().sum()
# Out:
# City                        555
# Country                     555
# Date                        555
# Lat                         555
# Lng                         555
# Max Temp                    555
# Humidity                    555
# Cloudiness                  555
# Wind Speed                  555
# Current Description         555
# Rain inches (last 3 hrs)    555
# Snow inches (last 3 hrs)    555
# dtype: int64
